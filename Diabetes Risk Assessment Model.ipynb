# %% [markdown]
# ### This Diabetes Risk Assessment model aims to predict the likelihood of diabetes given various parameters of the patient.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Import the data into a **Pandas** Dataframe

# %%
df = pd.read_csv(r"C:\Users\henry\OneDrive - Louisiana State University\Laptop Desktop\Personal Career\Personal Projects\Kaggle\Diabetes Risk Assessment\Healthcare-Diabetes.csv")

# %% [markdown]
# # Perform Exploratory Data Analysis (EDA) on the Dataset

# %%
#Print the first 5 rows of the dataset
df.head()
# Out:
#    Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0   1            6      148             72             35        0  33.6
# 1   2            1       85             66             29        0  26.6
# 2   3            8      183             64              0        0  23.3
# 3   4            1       89             66             23       94  28.1
# 4   5            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Print the last 5 rows of the dataset
df.tail()
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 2763                     0.370   33        0
# 2764                     0.719   36        1
# 2765                     0.382   42        0
# 2766                     0.319   26        1
# 2767                     0.547   25        0

# %%
# Show basic statistics of the data
df.describe()
# Out:
#                 Id  Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count  2768.000000  2768.000000  2768.000000    2768.000000    2768.000000
# mean   1384.500000     3.742775   121.102601      69.134393      20.824422
# std     799.197097     3.323801    32.036508      19.231438      16.059596
# min       1.000000     0.000000     0.000000       0.000000       0.000000
# 25%     692.750000     1.000000    99.000000      62.000000       0.000000
# 50%    1384.500000     3.000000   117.000000      72.000000      23.000000
# 75%    2076.250000     6.000000   141.000000      80.000000      32.000000
# max    2768.000000    17.000000   199.000000     122.000000     110.000000
#
#            Insulin          BMI  DiabetesPedigreeFunction          Age  \
# count  2768.000000  2768.000000               2768.000000  2768.000000
# mean     80.127890    32.137392                  0.471193    33.132225
# std     112.301933     8.076127                  0.325669    11.777230
# ...

# %%
# Show basic info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   int64
#  3   BloodPressure             2768 non-null   int64
#  4   SkinThickness             2768 non-null   int64
#  5   Insulin                   2768 non-null   int64
#  6   BMI                       2768 non-null   float64
#  7   DiabetesPedigreeFunction  2768 non-null   float64
#  8   Age                       2768 non-null   int64
#  9   Outcome                   2768 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 216.4 KB

# %%
#Print the shape of the dataset
df.shape
# Out:
# (2768, 10)

# %%
# Print the various columns of the dataset
df.columns.to_list()
# Out:
# ['Id',
#  'Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# ### Create data visualizations of each column

# %% [markdown]
# ### Pregnancies

# %%
sns.boxplot(data = df, x = "Pregnancies")
# Out:
# <Axes: xlabel='Pregnancies'>

# %%
sns.histplot(data = df, x = "Pregnancies")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Count'>

# %% [markdown]
# ### Glucose

# %%
sns.boxplot(data = df, x = "Glucose")
# Out:
# <Axes: xlabel='Glucose'>

# %%
sns.histplot(data = df, x = "Glucose")
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %% [markdown]
# ### Blood Pressure

# %%
sns.boxplot(data = df, x = "BloodPressure")
# Out:
# <Axes: xlabel='BloodPressure'>

# %%
sns.histplot(data = df, x = "BloodPressure")
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %% [markdown]
# ### Skin Thickness

# %%
sns.boxplot(data = df, x = "SkinThickness")
# Out:
# <Axes: xlabel='SkinThickness'>

# %%
sns.histplot(data = df, x = "SkinThickness")
# Out:
# <Axes: xlabel='SkinThickness', ylabel='Count'>

# %% [markdown]
# ### Insulin

# %%
sns.boxplot(data = df, x = "Insulin")
# Out:
# <Axes: xlabel='Insulin'>

# %%
sns.histplot(data = df, x = "Insulin")
# Out:
# <Axes: xlabel='Insulin', ylabel='Count'>

# %% [markdown]
# ### BMI

# %%
sns.boxplot(data = df, x = "BMI")
# Out:
# <Axes: xlabel='BMI'>

# %%
sns.histplot(data = df, x = "BMI")
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %% [markdown]
# ### DiabetesPedigreeFunction

# %%
sns.boxplot(data = df, x = "DiabetesPedigreeFunction")
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction'>

# %%
sns.histplot(data = df, x = "DiabetesPedigreeFunction")
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Count'>

# %% [markdown]
# ### Age

# %%
sns.boxplot(data = df, x = "Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.histplot(data = df, x = "Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.columns.to_list()
# Out:
# ['Id',
#  'Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# ### Determine the amount of Outcomes

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    1816
# 1     952
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x = 'Outcome')
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>
